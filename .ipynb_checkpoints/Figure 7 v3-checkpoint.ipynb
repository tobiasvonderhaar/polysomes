# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from polan import compare_profiles

# %% [markdown]
# <h1>To do:</h1>
# <p>Try to scale alpha with number of RNAs, rather than linewidth</p>

# %%
GSE100626 = pd.read_csv('Data/GSE100626_all_data.csv')
headers = list(GSE100626.columns)[1:]
genes = set([header.split('_')[0] for header in headers])
genes = sorted(genes)

# %%
idx=1
#idx += 1
gene = genes[idx]
r = gene + '_RNA'
ri = gene + '_Ribo'
fig,ax = compare_profiles(dats1 = GSE100626,dats2 = GSE100626,dats1_columns = ['Transcript','WT_RNA','WT_Ribo'],dats2_columns = ['Transcript',r,ri],conditions = ['WT',gene])
fig.suptitle(gene)
plt.show()
