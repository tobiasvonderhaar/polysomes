# %% [markdown]
# <h1>Modelling of HEK293 polysome</h1>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from polan import find_poly_peaks, fit_peaks
def normpdf(x,mu,sigma):
    return 1/(np.sqrt(2 * np.pi * sigma ** 2)) * np.exp(-1 * ((x - mu) ** 2 / (2 * sigma ** 2)))

# %%
#read in the data file containing the polysome profile
HEK_trace = pd.read_csv('Data/poly_HEK.csv')
#ensure that data are in ascending x axis order
HEK_trace = HEK_trace.sort_values('x')
#normalise x axis 
HEK_trace.x = HEK_trace.x / max(HEK_trace.x)
#detect well separated peaks
autopeaks = np.asarray(find_poly_peaks(HEK_trace))
#extrapolate additional peaks up to gradient end
extrapeaks,peakfun = fit_peaks(autopeaks,0.99,mode=0.37)

# %%
#adjust drift
x = np.linspace(0,1,num=400)
#define the baseline drifts: 
#'debris' represents the initial debris peak
debris = np.exp((-x)*8)*0.09
#'drift' represent the absorption of the sucrose gradient
drift = 0.289 + 0.106*x

baseline = drift + debris

plt.close()
fig,ax = plt.subplots()
ax.set_ylim((0.3,0.55))
ax.scatter(HEK_trace.x,HEK_trace.y,s=2,c='black')
ax.plot(x,baseline,c ='orange')
plt.show()

# %%
#list of peak locations
peak_locs = [0.17, 0.30, 0.38, 0.53, 0.62, 0.67, 0.72, 0.75, 0.78, 0.81, 0.83, 0.85, 0.86, 0.88, 0.90, 0.91, 0.92, 0.94, 0.95, 0.96, 0.97, 0.98]
#list of peak widths.These were manually adjusted to achieve a good fit in the figure below.
peak_widths = [0.0357, 0.027, 0.0253, 0.0195, 0.0217, 0.0175, 0.015, 0.012, 0.012, 0.012, 0.011, 0.011, 0.01, 0.01, 0.009, 0.009, 0.009, 0.009, 0.009, 0.009, 0.009, 0.009, 0.009]
#list of peak scaling factors. These were manually adjusted to achieve a good fit in the figure below.
peak_scales = [0.0048, 0.008, 0.0033, 0.002, 0.0032, 0.004, 0.0042, 0.0032, 0.00312, 0.00306, 0.00243, 0.00253, 0.00213, 0.00211, 0.00166, 0.00149, 0.00124, 0.00097, 0.00079, 0.00043, 0.00035, 0.00036, 0.00036]

# %%
print(peak_scales)
# Out:
# [0.0048114, 0.00795906, 0.003292880879684032, 0.0019244686787812377, 0.003152991795966426, 0.00395647284375, 0.004198640633570251, 0.00319725, 0.0031231875905685, 0.0030606257794921206, 0.002428977767040001, 0.0025364835891250916, 0.0021306462148650766, 0.002108143291049757, 0.00166154500174572, 0.0014899128806862723, 0.0012415940672385601, 0.0009737992684224002, 0.000787185, 0.000427329, 0.000349809, 0.000361, 0.000361]

# %%
factor = 0.95
n = 1
#peak_widths[n] = peak_widths[n] * factor; peak_scales[n] = peak_scales[n] * factor
#peak_scales[n] = peak_scales[n] * factor
#peak_locs[n] = peak_locs[n] * factor
#generate a vector of values for the x-axis, starting after the initial debris peak

#construct peaks
indiv_traces = []
sum_trace = drift+debris
for loc in range(len(peak_locs)):
    this_peak = normpdf(x,peak_locs[loc],peak_widths[loc])*peak_scales[loc]
    indiv_traces.append(this_peak)
    sum_trace += this_peak
plt.close()
fig,ax = plt.subplots(figsize=(10,5))
ax.scatter(HEK_trace.x,HEK_trace.y,s=2,c='black')
ax.plot(x,sum_trace,c='orange',alpha=0.7)
plt.show()

# %%
fig,ax = plt.subplots(1,3,figsize=(12,3))
#plot fitted trace
ax[0].plot(x,sum_trace,c='orange',alpha=0.7)
ax[0].set_ylim((0.25,0.6))
ax[0].set_xlabel('Relative gradient position')
ax[0].set_ylabel(r'$oD_{254}$')
#plot overlay
ax[1].scatter(trace['x'],trace['y'],c='black',s=2)
ax[1].plot(x,sum_trace,c='orange',alpha=0.7)
ax[1].set_ylim((0.25,0.6))
ax[1].set_xlabel('Relative gradient position')
ax[1].set_ylabel(r'$oD_{254}$')
#plot separated peaks
ax[2].set_prop_cycle(cycler('color', cm.cool(np.linspace(0, 1, 25))))
display_limit = 0.0001
for n in range(len(indiv_traces)):
    y = indiv_traces[n]
    ax[2].plot(x[y >= display_limit], y[y >= display_limit])
ax[2].set_xlabel('Relative gradient position')
ax[2].set_ylabel(r'$oD_{254}$')
fig.tight_layout()
#plt.savefig('isol_peaks.svg')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-45-6b9148991d69> in <module>
#       6 ax[0].set_ylabel(r'$oD_{254}$')
#       7 #plot overlay
# ----> 8 ax[1].scatter(trace['x'],trace['y'],c='black',s=2)
#       9 ax[1].plot(x,sum_trace,c='orange',alpha=0.7)
#      10 ax[1].set_ylim((0.25,0.6))
#
# NameError: name 'trace' is not defined

# %%
#Save the results of the peak fitting as a .json file
import json

model = {'drift':[0.289,0.106],'debris':[8,0.09],'mu':peak_locs,'sigma':peak_widths,'factor':peak_scales}
with open("Native OE T0 model.json", "w") as write_file:
    json.dump(model, write_file)

# %%
type(peak_scales[0])
# Out:
# float

# %%
with open("Native OE T0 model.json", "r") as read_file:
    data = json.load(read_file)
